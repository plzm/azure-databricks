# %% [markdown]
# References
#
# https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrameStatFunctions<br>
# https://docs.azuredatabricks.net/user-guide/visualizations/index.html<br>

# %% [markdown]
# #### Get a dataframe for notebook tasks

# %%
# %run ./adb_3_ingest_to_df

# %% [markdown]
# ### Data exploration

# %%
df_flights_full.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- DayofMonth: integer (nullable = true)
# -- DayOfWeek: integer (nullable = true)
# -- Carrier: string (nullable = true)
# -- OriginAirportID: integer (nullable = true)
# -- DestAirportID: integer (nullable = true)
# -- DepDelay: integer (nullable = true)
# -- ArrDelay: integer (nullable = true)
# -- OriginCity: string (nullable = true)
# -- OriginState: string (nullable = true)
# -- OriginAirportName: string (nullable = true)
# -- DestCity: string (nullable = true)
# -- DestState: string (nullable = true)
# -- DestAirportName: string (nullable = true)
#
# </div>

# %%
df_flights_full.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>2719418
# </div>

# %%
# See if there are duplicate rows - if so, this will differ from just count()

df_flights_full.distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>2696983
# </div>

# %%
# Summary statistics

display(df_flights_full.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>DayofMonth</th><th>DayOfWeek</th><th>Carrier</th><th>OriginAirportID</th><th>DestAirportID</th><th>DepDelay</th><th>ArrDelay</th><th>OriginCity</th><th>OriginState</th><th>OriginAirportName</th><th>DestCity</th><th>DestState</th><th>DestAirportName</th></tr></thead><tbody><tr><td>count</td><td>2719418</td><td>2719418</td><td>2719418</td><td>2719418</td><td>2719418</td><td>2691974</td><td>2690385</td><td>2719418</td><td>2719418</td><td>2719418</td><td>2719418</td><td>2719418</td><td>2719418</td></tr><tr><td>mean</td><td>15.79747468024408</td><td>3.8983907586108497</td><td>null</td><td>12742.26441172339</td><td>12742.455345592329</td><td>10.53686662649788</td><td>6.63768791455498</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>stddev</td><td>8.799860168985386</td><td>1.985988139037331</td><td>null</td><td>1501.9729397025624</td><td>1501.9692528927906</td><td>36.0995280664314</td><td>38.648814893900756</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>min</td><td>1</td><td>1</td><td>9E</td><td>10140</td><td>10140</td><td>-63</td><td>-94</td><td>Albuquerque</td><td>AK</td><td>Albuquerque International Sunport</td><td>Albuquerque</td><td>AK</td><td>Albuquerque International Sunport</td></tr><tr><td>max</td><td>31</td><td>7</td><td>YV</td><td>15376</td><td>15376</td><td>1863</td><td>1845</td><td>West Palm Beach/Palm Beach</td><td>WI</td><td>William P Hobby</td><td>West Palm Beach/Palm Beach</td><td>WI</td><td>William P Hobby</td></tr></tbody></table></div>

# %%
# Get top rows - head(n) or take(n)

display(df_flights_full.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DayofMonth</th><th>DayOfWeek</th><th>Carrier</th><th>OriginAirportID</th><th>DestAirportID</th><th>DepDelay</th><th>ArrDelay</th><th>OriginCity</th><th>OriginState</th><th>OriginAirportName</th><th>DestCity</th><th>DestState</th><th>DestAirportName</th></tr></thead><tbody><tr><td>19</td><td>5</td><td>DL</td><td>11433</td><td>13303</td><td>-3</td><td>1</td><td>Detroit</td><td>MI</td><td>Detroit Metro Wayne County</td><td>Miami</td><td>FL</td><td>Miami International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>14869</td><td>12478</td><td>0</td><td>-8</td><td>Salt Lake City</td><td>UT</td><td>Salt Lake City International</td><td>New York</td><td>NY</td><td>John F. Kennedy International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>14057</td><td>14869</td><td>-4</td><td>-15</td><td>Portland</td><td>OR</td><td>Portland International</td><td>Salt Lake City</td><td>UT</td><td>Salt Lake City International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>15016</td><td>11433</td><td>28</td><td>24</td><td>St. Louis</td><td>MO</td><td>Lambert-St. Louis International</td><td>Detroit</td><td>MI</td><td>Detroit Metro Wayne County</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>11193</td><td>12892</td><td>-6</td><td>-11</td><td>Cincinnati</td><td>OH</td><td>Cincinnati/Northern Kentucky International</td><td>Los Angeles</td><td>CA</td><td>Los Angeles International</td></tr></tbody></table></div>

# %%
df_flights_full.show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+---------+-------+---------------+-------------+--------+--------+--------------+-----------+--------------------+--------------+---------+--------------------+
# DayofMonth|DayOfWeek|Carrier|OriginAirportID|DestAirportID|DepDelay|ArrDelay|    OriginCity|OriginState|   OriginAirportName|      DestCity|DestState|     DestAirportName|
# +----------+---------+-------+---------------+-------------+--------+--------+--------------+-----------+--------------------+--------------+---------+--------------------+
#         19|        5|     DL|          11433|        13303|      -3|       1|       Detroit|         MI|Detroit Metro Way...|         Miami|       FL| Miami International|
#         19|        5|     DL|          14869|        12478|       0|      -8|Salt Lake City|         UT|Salt Lake City In...|      New York|       NY|John F. Kennedy I...|
#         19|        5|     DL|          14057|        14869|      -4|     -15|      Portland|         OR|Portland Internat...|Salt Lake City|       UT|Salt Lake City In...|
#         19|        5|     DL|          15016|        11433|      28|      24|     St. Louis|         MO|Lambert-St. Louis...|       Detroit|       MI|Detroit Metro Way...|
#         19|        5|     DL|          11193|        12892|      -6|     -11|    Cincinnati|         OH|Cincinnati/Northe...|   Los Angeles|       CA|Los Angeles Inter...|
#         19|        5|     DL|          10397|        15016|      -1|     -19|       Atlanta|         GA|Hartsfield-Jackso...|     St. Louis|       MO|Lambert-St. Louis...|
#         19|        5|     DL|          15016|        10397|       0|      -1|     St. Louis|         MO|Lambert-St. Louis...|       Atlanta|       GA|Hartsfield-Jackso...|
#         19|        5|     DL|          10397|        14869|      15|      24|       Atlanta|         GA|Hartsfield-Jackso...|Salt Lake City|       UT|Salt Lake City In...|
#         19|        5|     DL|          10397|        10423|      33|      34|       Atlanta|         GA|Hartsfield-Jackso...|        Austin|       TX|Austin - Bergstro...|
#         19|        5|     DL|          11278|        10397|     323|     322|    Washington|         DC|Ronald Reagan Was...|       Atlanta|       GA|Hartsfield-Jackso...|
# +----------+---------+-------+---------------+-------------+--------+--------+--------------+-----------+--------------------+--------------+---------+--------------------+
# only showing top 10 rows
#
# </div>

# %%
# limit(n), head(n), take(n)

display(df_flights_full.head(7))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DayofMonth</th><th>DayOfWeek</th><th>Carrier</th><th>OriginAirportID</th><th>DestAirportID</th><th>DepDelay</th><th>ArrDelay</th><th>OriginCity</th><th>OriginState</th><th>OriginAirportName</th><th>DestCity</th><th>DestState</th><th>DestAirportName</th></tr></thead><tbody><tr><td>19</td><td>5</td><td>DL</td><td>11433</td><td>13303</td><td>-3</td><td>1</td><td>Detroit</td><td>MI</td><td>Detroit Metro Wayne County</td><td>Miami</td><td>FL</td><td>Miami International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>14869</td><td>12478</td><td>0</td><td>-8</td><td>Salt Lake City</td><td>UT</td><td>Salt Lake City International</td><td>New York</td><td>NY</td><td>John F. Kennedy International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>14057</td><td>14869</td><td>-4</td><td>-15</td><td>Portland</td><td>OR</td><td>Portland International</td><td>Salt Lake City</td><td>UT</td><td>Salt Lake City International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>15016</td><td>11433</td><td>28</td><td>24</td><td>St. Louis</td><td>MO</td><td>Lambert-St. Louis International</td><td>Detroit</td><td>MI</td><td>Detroit Metro Wayne County</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>11193</td><td>12892</td><td>-6</td><td>-11</td><td>Cincinnati</td><td>OH</td><td>Cincinnati/Northern Kentucky International</td><td>Los Angeles</td><td>CA</td><td>Los Angeles International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>10397</td><td>15016</td><td>-1</td><td>-19</td><td>Atlanta</td><td>GA</td><td>Hartsfield-Jackson Atlanta International</td><td>St. Louis</td><td>MO</td><td>Lambert-St. Louis International</td></tr><tr><td>19</td><td>5</td><td>DL</td><td>15016</td><td>10397</td><td>0</td><td>-1</td><td>St. Louis</td><td>MO</td><td>Lambert-St. Louis International</td><td>Atlanta</td><td>GA</td><td>Hartsfield-Jackson Atlanta International</td></tr></tbody></table></div>

# %%
df_flights_full.explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# InMemoryTableScan [DayofMonth#26546, DayOfWeek#26547, Carrier#26548, OriginAirportID#26549, DestAirportID#26550, DepDelay#26551, ArrDelay#26552, OriginCity#26633, OriginState#26644, OriginAirportName#26655, DestCity#26721, DestState#26735, DestAirportName#26749]
#    +- InMemoryRelation [DayofMonth#26546, DayOfWeek#26547, Carrier#26548, OriginAirportID#26549, DestAirportID#26550, DepDelay#26551, ArrDelay#26552, OriginCity#26633, OriginState#26644, OriginAirportName#26655, DestCity#26721, DestState#26735, DestAirportName#26749], true, 10000, StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(3) Project [DayofMonth#443, DayOfWeek#444, Carrier#445, OriginAirportID#446, DestAirportID#447, DepDelay#448, ArrDelay#449, OriginCity#1761, OriginState#1772, OriginAirportName#1783, city#436 AS DestCity#4002, state#437 AS DestState#4016, name#438 AS DestAirportName#4030]
#             +- *(3) BroadcastHashJoin [DestAirportID#447], [airport_id#435], LeftOuter, BuildRight, false
#                :- *(3) Project [DayofMonth#443, DayOfWeek#444, Carrier#445, OriginAirportID#446, DestAirportID#447, DepDelay#448, ArrDelay#449, city#436 AS OriginCity#1761, state#437 AS OriginState#1772, name#438 AS OriginAirportName#1783]
#                :  +- *(3) BroadcastHashJoin [OriginAirportID#446], [airport_id#435], LeftOuter, BuildRight, false
#                :     :- *(3) FileScan csv [DayofMonth#443,DayOfWeek#444,Carrier#445,OriginAirportID#446,DestAirportID#447,DepDelay#448,ArrDelay#449] Batched: false, Format: CSV, Location: InMemoryFileIndex[dbfs:/mnt/hack/csv/sample/dat202/raw-flight-data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;DayofMonth:int,DayOfWeek:int,Carrier:string,OriginAirportID:int,DestAirportID:int,DepDelay...
#                :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)))
#                :        +- *(1) Filter isnotnull(airport_id#435)
#                :           +- InMemoryTableScan [airport_id#435, city#436, state#437, name#438], [isnotnull(airport_id#435)]
#                :                 +- InMemoryRelation [airport_id#435, city#436, state#437, name#438], true, 10000, StorageLevel(disk, memory, deserialized, 1 replicas)
#                :                       +- *(1) FileScan csv [airport_id#2,city#3,state#4,name#5] Batched: false, Format: CSV, Location: InMemoryFileIndex[dbfs:/mnt/hack/csv/sample/dat202/airports.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;airport_id:int,city:string,state:string,name:string&gt;
#                +- ReusedExchange [airport_id#435, city#436, state#437, name#438], BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)))
# </div>

# %% [markdown]
# #### Stats

# %%
df_flights_full.approxQuantile("ArrDelay", [0.25, 0.5, 0.75], 0.1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">25</span><span class="ansired">]: </span>[-5.0, 2.0, 941.0]
# </div>

# %%
display(df_flights_full.freqItems(["DestAirportID"]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DestAirportID_freqItems</th></tr></thead><tbody><tr><td>List(14869, 13891, 11298, 14492, 13487, 12339, 11292, 14100, 11193, 14683, 12889, 11259, 10299, 10792, 14635, 10140, 10529, 13232, 13851, 14524, 10397, 12954, 10693, 12266, 13244, 13495, 14027, 13830, 10800, 12191, 14730, 15376, 12451, 13303, 14057, 12478, 15304, 12173, 10821, 13342, 14679, 11066, 14843, 11057, 13931, 12953, 14747, 13796, 13204, 10423, 11697, 11042, 14831, 13198, 14122, 11278, 13871, 14107, 14771, 11433, 13930, 14307, 14908, 15016, 14570, 14893, 10721, 11618, 12264, 12892)</td></tr></tbody></table></div>
