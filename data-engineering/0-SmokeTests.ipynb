# %%
# %run ./0-Config

# %%
# %run ./0-Functions

# %%
# Smoke test - top-level listing

display(dbutils.fs.ls(adls2uri_raw))

# %%
# List all files recursively

GetFilesRecursive(adls2uri_raw)

# %%
# Copy a file from ADLS2 to DBFS. From here, files can be copied to a local system with Databricks CLI for in-depth analysis

dbutils.fs.ls('/Shared/')
